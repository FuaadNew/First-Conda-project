# %%
# %matplotlib inline
import matplotlib.pyplot as plt 
import pandas as pd
import numpy as np

# %%
plt.plot([1,2,3,4])
plt.show()

# %%
x = [1,2,3,4]
y = [11,22,33,44]
plt.plot(x,y)
plt.show()

# %%
fig,ax = plt.subplots()
ax.plot(x,[50,100,200,400])
plt.show()

# %%
##import matplotlib
import matplotlib.pyplot as plt
##prepare data
x = [1,2,3,4]
y = [11,22,33,44]

##set up plot
fig,ax = plt.subplots(figsize = (10,10))


##customize plot
ax.set(title = "simple plot", xlabel = "x-axes", ylabel = "y-axes")

##plot data
ax.plot(x,y)

plt.show()

##save and show 
fig.savefig("./images/sample-plot")

# %%
#create data
x = np.linspace(0,10,100)
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %% [markdown]
# # Making plots with Numpy Arrays
#
# We want:
# * Line plot
# * Scatter plot
# * Bar plot
# * Histogram
# * Subplot

# %%
#plot the data
fig,ax = plt.subplots()
ax.plot(x,x**2)
plt.show()

# %%
#use same data to make scatter plot
fig,ax = plt.subplots()
ax.scatter(x,np.exp(x))
plt.show()

# %%
#make plot from dictionary
nut_butter_prices = {"Almond butter" : 10, "Peanut Butter": 8, "Cashew Butter": 12}
fig,ax = plt.subplots()
ax.bar(nut_butter_prices.keys(),nut_butter_prices.values())
ax.set(title = "nut butters by price", ylabel = "Price ($)")
plt.show()

# %%
fig,ax = plt.subplots()
ax.barh(nut_butter_prices.keys(),nut_butter_prices.values())
ax.set(title = "nut butters by price", ylabel = "Price ($)")
plt.show()

# %%
x = np.random.randn(1000)
fig,ax = plt.subplots()
ax.hist(x)
plt.show()

# %%
#subplots options
#option 1

fig,((ax1,ax2),(ax3,ax4)) = plt.subplots(nrows=2, ncols=2, figsize = (10,5))
ax1.plot(x,x/2)
ax2.scatter(np.random.random(10), np.random.random(10))
ax3.bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax4.hist(np.random.randn(1000))
plt.show()

# %%
fig,ax = plt.subplots(nrows=2, ncols=2, figsize = (10,5))

#plot to each index

ax[0][0].plot(x,x/2)
ax[0][1].scatter(np.random.random(10), np.random.random(10))
ax[1][0].bar(nut_butter_prices.keys(),nut_butter_prices.values())
ax[1][1].hist(np.random.randn(1000))


plt.show()

# %%
#plotting from pandas dataframes

car_sales = pd.read_csv("car-sales-missing-data.csv")
car_sales
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
ts = pd.Series(np.random.randn(1000),index = pd.date_range("1/1/2025", periods=1000))
ts = ts.cumsum()
ts.plot()
plt.show()

# %%
car_sales
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
#remove $ and commas
car_sales["Price"] = car_sales["Price"].str.replace(r'[\$\,\.]','', regex= True)
car_sales["Price"] = pd.to_numeric(car_sales["Price"])

car_sales
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   4000.0
# 1   Honda    Red   87899.0    4.0   5000.0
# 2  Toyota   Blue       NaN    3.0   7000.0
# 3     BMW  Black   11179.0    5.0  22000.0
# 4  Nissan  White  213095.0    4.0   3500.0
# 5  Toyota  Green       NaN    4.0   4500.0
# 6   Honda    NaN       NaN    4.0   7500.0
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   9700.0

# %%
car_sales["Sale Date"] = pd.date_range("1/1/2025", periods=len(car_sales))
car_sales.dropna
# Out:
# <bound method DataFrame.dropna of      Make Colour  Odometer  Doors    Price  Sale Date
# 0  Toyota  White  150043.0    4.0   4000.0 2025-01-01
# 1   Honda    Red   87899.0    4.0   5000.0 2025-01-02
# 2  Toyota   Blue       NaN    3.0   7000.0 2025-01-03
# 3     BMW  Black   11179.0    5.0  22000.0 2025-01-04
# 4  Nissan  White  213095.0    4.0   3500.0 2025-01-05
# 5  Toyota  Green       NaN    4.0   4500.0 2025-01-06
# 6   Honda    NaN       NaN    4.0   7500.0 2025-01-07
# 7   Honda   Blue       NaN    4.0      NaN 2025-01-08
# 8  Toyota  White   60000.0    NaN      NaN 2025-01-09
# 9     NaN  White   31600.0    4.0   9700.0 2025-01-10>

# %%
car_sales["Total Sales"] = car_sales["Price"].cumsum()
car_sales
# Out:
#      Make Colour  Odometer  Doors    Price  Sale Date  Total Sales
# 0  Toyota  White  150043.0    4.0   4000.0 2025-01-01       4000.0
# 1   Honda    Red   87899.0    4.0   5000.0 2025-01-02       9000.0
# 2  Toyota   Blue       NaN    3.0   7000.0 2025-01-03      16000.0
# 3     BMW  Black   11179.0    5.0  22000.0 2025-01-04      38000.0
# 4  Nissan  White  213095.0    4.0   3500.0 2025-01-05      41500.0
# 5  Toyota  Green       NaN    4.0   4500.0 2025-01-06      46000.0
# 6   Honda    NaN       NaN    4.0   7500.0 2025-01-07      53500.0
# 7   Honda   Blue       NaN    4.0      NaN 2025-01-08          NaN
# 8  Toyota  White   60000.0    NaN      NaN 2025-01-09          NaN
# 9     NaN  White   31600.0    4.0   9700.0 2025-01-10      63200.0

# %%
car_sales.plot(x = "Sale Date", y = "Total Sales")
plt.show()

# %%
car_sales.plot(x = "Odometer", y = "Price", kind = "scatter")
plt.show()

# %%
x = np.random.rand(10,4)

df = pd.DataFrame(x, columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  0.282708  0.424708  0.420632  0.748669
# 1  0.426213  0.144357  0.164924  0.706793
# 2  0.028379  0.676130  0.893328  0.833541
# 3  0.756480  0.091757  0.497651  0.109834
# 4  0.372149  0.508123  0.780490  0.662864
# 5  0.988680  0.559505  0.784689  0.577909
# 6  0.126379  0.709196  0.638512  0.895170
# 7  0.559378  0.233116  0.954026  0.364782
# 8  0.573715  0.053988  0.137437  0.636349
# 9  0.425944  0.660788  0.632701  0.695366

# %%
df.plot.bar()
plt.show()

# %%
df.plot(kind = "bar")
plt.show()

# %%
car_sales.plot(x = "Make", y = "Odometer", kind = "bar")
plt.show()

# %%
heart_disease = pd.read_csv("heart-disease.csv")
heart_disease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease["age"].plot(kind= "hist")
plt.show()

# %%
heart_disease["age"].plot(kind= "hist", bins = 60)
plt.show()

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease.plot.hist(figsize = (10,30), subplots = True)
plt.show()

# %%
#pyplot
over_50 = heart_disease[heart_disease['age'] > 50]
over_50
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 3        2   0     2       1
# ...

# %%
over_50.plot( kind = "scatter", x = "age", y = "chol", c = "target" )
plt.show()

# %%
## OO method
fig,ax = plt.subplots(figsize = (10,6))
over_50.plot(kind = "scatter", x = "age", y = "chol", c = "target",ax = ax)
ax.set_xlim([45,100])
plt.show()

# %%
fig,ax = plt.subplots(figsize = (10,6))
scatter = ax.scatter(x = over_50["age"], 
                        y = over_50["chol"], c = over_50["target"])
ax.set(title = "Heart disease and Cholosterol Levels",
        xlabel = "Age",
       ylabel = "Cholosterol"
      )

#add Legend
ax.legend(*scatter.legend_elements(), title = "Target")

#horizontal Line

ax.axhline(over_50["chol"].mean(),
          linestyle = "--")

plt.show()

# %%
#subplot of chol, age, thalach

fig,(ax0, ax1) = plt.subplots(nrows = 2,
                              ncols = 1,
                              figsize = (10,10))


#add data to ax0

scatter0 = ax0.scatter(x = over_50["age"], 
                        y = over_50["chol"], c = over_50["target"])

#customize ax0
ax0.set(title = "Heart disease and Cholosterol Levels",
        xlabel = "Age",
       ylabel = "Cholosterol"
      )

#add Legend to ax0
ax0.legend(*scatter0.legend_elements(), title = "Target")

#horizontal Line

ax0.axhline(over_50["chol"].mean(),
          linestyle = "--")


#add data to ax1

scatter1 = ax1.scatter(x = over_50["age"], 
                        y = over_50["thalach"], c = over_50["target"])

#customize ax1
ax1.set(title = "Heart disease and Cholosterol Levels",
        xlabel = "Age",
       ylabel = "Max heart rate"
      )

#add Legend to ax1
ax1.legend(*scatter1.legend_elements(), title = "Target")

#horizontal Line

ax1.axhline(over_50["thalach"].mean(),
          linestyle = "--")


fig.suptitle("Heart disease analysis", fontsize = 16, fontweight = "bold")


plt.show()

# %%
##customizing matplotlib plots
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer  Doors    Price  Sale Date  Total Sales
# 0  Toyota  White  150043.0    4.0   4000.0 2025-01-01       4000.0
# 1   Honda    Red   87899.0    4.0   5000.0 2025-01-02       9000.0
# 2  Toyota   Blue       NaN    3.0   7000.0 2025-01-03      16000.0
# 3     BMW  Black   11179.0    5.0  22000.0 2025-01-04      38000.0
# 4  Nissan  White  213095.0    4.0   3500.0 2025-01-05      41500.0

# %%
car_sales["Price"].plot()
plt.show()

# %%
plt.style.use("seaborn-v0_8-whitegrid")

# %%
car_sales["Price"].plot()
plt.show()

# %%
plt.style.use("seaborn-v0_8")

# %%
car_sales["Price"].plot()
plt.show()

# %%
car_sales.plot(x = "Odometer", y = "Price", kind = "scatter")
plt.show()

# %%
plt.style.use("ggplot")

# %%
car_sales["Price"].plot()
plt.show()

# %%
#create some data
x = np.random.randn(10,4)
x
# Out:
# array([[ 0.20407224, -0.0797269 , -0.86649517, -0.42390892],
#        [-1.96262149, -1.23449959,  1.89257932,  0.61940641],
#        [ 1.42832553,  0.82834687, -0.14315889, -0.909196  ],
#        [-1.53550662,  0.24812752, -0.38311985,  0.01651035],
#        [ 2.06306238,  0.38032038, -0.97183819,  1.14790118],
#        [ 2.18862467, -0.85183794, -1.80523103,  0.07617288],
#        [ 0.71682865, -1.02268669,  0.79555404, -1.33123138],
#        [ 0.31939733,  0.92045648, -1.02278383,  0.99495236],
#        [ 2.0046484 ,  0.63286111, -0.44307545,  1.40161923],
#        [-1.40448883, -1.1190709 ,  0.95794443, -0.42235896]])

# %%
df = pd.DataFrame(x, columns= ['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  0.204072 -0.079727 -0.866495 -0.423909
# 1 -1.962621 -1.234500  1.892579  0.619406
# 2  1.428326  0.828347 -0.143159 -0.909196
# 3 -1.535507  0.248128 -0.383120  0.016510
# 4  2.063062  0.380320 -0.971838  1.147901
# 5  2.188625 -0.851838 -1.805231  0.076173
# 6  0.716829 -1.022687  0.795554 -1.331231
# 7  0.319397  0.920456 -1.022784  0.994952
# 8  2.004648  0.632861 -0.443075  1.401619
# 9 -1.404489 -1.119071  0.957944 -0.422359

# %%
ax = df.plot(kind = "bar");
plt.show()

# %%
#customize with set
ax = df.plot(kind = "bar");

#add some labels/titles
ax.set(title= "Random bar graph from dataframe", xlabel= "Row number",
       ylabel="Random Number"
      )
#make legend visible
ax.legend().set_visible = True
plt.show()

# %%
plt.style.use("seaborn-v0_8-whitegrid")
#change style from within existing style
fig,ax = plt.subplots(figsize = (10,6))
scatter = ax.scatter(x = over_50["age"], 
                        y = over_50["chol"], c = over_50["target"],
                    cmap= "winter")
ax.set(title = "Heart disease and Cholosterol Levels",
        xlabel = "Age",
       ylabel = "Cholosterol"
      )

#add Legend
ax.legend(*scatter.legend_elements(), title = "Target")

#horizontal Line

ax.axhline(over_50["chol"].mean(),
          linestyle = "--")

plt.show()

# %%
#customizing the x and y limitations 

#subplot of chol, age, thalach

fig,(ax0, ax1) = plt.subplots(nrows = 2,
                              ncols = 1,
                              figsize = (10,10))


#add data to ax0

scatter0 = ax0.scatter(x = over_50["age"], 
                        y = over_50["chol"], c = over_50["target"],
                      cmap="winter")

#customize ax0
ax0.set(title = "Heart disease and Cholosterol Levels",
        xlabel = "Age",
       ylabel = "Cholosterol"
      )

#add Legend to ax0
ax0.legend(*scatter0.legend_elements(), title = "Target")

#horizontal Line

ax0.axhline(over_50["chol"].mean(),
          linestyle = "--")


#add data to ax1

scatter1 = ax1.scatter(x = over_50["age"], 
                        y = over_50["thalach"], c = over_50["target"],
                      cmap="winter")

#customize ax1
ax1.set(title = "Heart disease and Cholosterol Levels",
        xlabel = "Age",
       ylabel = "Max heart rate"
      )

#add Legend to ax1
ax1.legend(*scatter1.legend_elements(), title = "Target")

#horizontal Line

ax1.axhline(over_50["thalach"].mean(),
          linestyle = "--")


fig.suptitle("Heart disease analysis", fontsize = 16, fontweight = "bold")


plt.show()
